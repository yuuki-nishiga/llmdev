# %%
noTax = int(input("税抜き価格を入力してください"))
noTax *= 1.1

if noTax < 2000:
    postage = 350
    print(f"送料は350円です\n送料込税込価格は{int(noTax+postage)}です。")
else:
    print(f"送料は無料です\n送料込税込価格は{int(noTax)}です。")
# Out:
# 送料は無料です
# 送料込税込価格は2200です。
