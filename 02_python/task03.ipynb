# %%
principal = int(input("元金を入力してください: "))
annualInterestRate = int(input("年利を入力してください: "))
i = 0

while i < 10:
    principal *= (1 + (annualInterestRate / 100))
    i += 1

print(f"10年後の金額: {principal:.2f}")
# Out:
# 10年後の金額: 1628.89
