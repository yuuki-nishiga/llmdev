# %%
fruits = ["apple", "banana", "cherry"]

# インデックスと要素を同時に取得
for index, fruit in enumerate(fruits):
    print(f"{index}番目の要素は「{fruit}」です。")
# Out:
# 1番目の要素は「apple」です。
# 2番目の要素は「banana」です。
# 3番目の要素は「cherry」です。
