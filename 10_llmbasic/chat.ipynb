# %%
import tiktoken
from tiktoken.core import Encoding

# OpenAI APIの特定のモデルに対応するトークナイザーを取得
encoding: Encoding = tiktoken.encoding_for_model(MODEL_NAME) # o200k_base

# テキストをトークンIDのリストに変換
tokens = encoding.encode("こんにちは！")
tokens_count = len(tokens)

# メッセージの設定
message = "言語モデルを使う上でのポイントは"

# APIへリクエスト
stream = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    stream=True,
)

for chunk in stream:
    if chunk.choices:
        if chunk.choices[0].delta.content is not None:
            print(chunk.choices[0].delta.content, end="")
# Out:
# 言語モデルを使う上でのポイントはいくつかあります。以下に主なものを挙げます。
#
# 1. **明確な目的を持つ**: 何を達成したいのかを明確にしましょう。質問応答、テキスト生成、翻訳など、使用目的によってアプローチが変わります。
#
# 2. **入力の工夫**: モデルへの入力は結果に大きく影響します。具体的で詳細なプロンプトを使用することで、より良い出力を得ることができます。
#
# 3. **コンテクストの提供**: 必要な背景情報や文脈を与えることで、モデルの応答の質が向上します。特に専門的な内容や特定のトピックに関する質問の場合、コンテクストは重要です。
#
# 4. **実験と調整**: モデルの出力が期待通りでない場合、入力を調整したり、異なる方法を試したりすることが重要です。プロンプトエンジニアリングを活用しましょう。
#
# 5. **モデルの限界を理解する**: 言語モデルは訓練データに基づいて応答を生成しますが、必ずしも正確な情報を提供するわけではありません。情報の信頼性を確認することが重要です。
#
# 6. **倫理的配慮**: モデルを使用する際には、バイアスや誤情報の生成といった倫理的な側面に配慮し、適切な使用を心掛ける必要があります。
#
# 7. **目的に応じたモデルの選択**: 使用する言語モデルのバージョンやタイプ（例えば、GPT系やその他のNNモデル）を選ぶ際には、自分のニーズに最も適したものを選ぶことが重要です。
#
# 8. **フィードバックの活用**: 使用した結果を評価し、必要に応じてフィードバックを取り入れることで、次回の使用時により良い結果を得ることができます。
#
# これらのポイントを意識して言語モデルを活用することで、より良い結果を得られるでしょう。
