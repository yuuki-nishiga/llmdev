# %%
# 必要なモジュールをインポート
import os
from dotenv import load_dotenv
from openai import OpenAI
from pprint import pprint

# 環境変数の取得
load_dotenv("../.env")

# OpenAI APIクライアントを生成
client = OpenAI(api_key=os.environ['API_KEY'])

# モデル名
MODEL_NAME = "gpt-4o-mini"

# メッセージを格納するリスト
messages=[]

role_message = input("キャラクターの設定")
messages.append({"role": "system", "content": role_message.strip()})
stream = client.chat.completions.create(
    model=MODEL_NAME,
    messages=messages,
)

while(True):
    # ユーザーからの質問を受付
    message = input("メッセージを入力:")
    # 質問が入力されなければ終了
    if message.strip()=="":
        break
    print(f"質問:{message}")

    # メッセージにユーザーからの質問を追加
    messages.append({"role": "user", "content": message.strip()})
    # やりとりが8を超えたら古いメッセージから削除
    if len(messages) > 8:
        del_message = messages.pop(0)

    # APIへリクエスト
    stream = client.chat.completions.create(
        model=MODEL_NAME,
        messages=messages,
        stream=True,
    )

    # 言語モデルからの回答を表示
    response_message = ""
    for chunk in stream:
        if chunk.choices:
            next = chunk.choices[0].delta.content
            if next is not None:
                response_message += next
                print(next, end='', flush=True)

    # メッセージに言語モデルからの回答を追加
    messages.append({"role": "assistant", "content": response_message})

print("\n---ご利用ありがとうございました！---")
# Out:
# 質問:こんにちは
# こんにちは、にゃ！今日はどんなことを話しましょうか、にゃ？質問:なにして遊ぶ？
# うーん、にゃーん！じゃあ、おもちゃの紐で遊んだり、お隣の猫ちゃんの話をしたりするのはどうかにゃ？それとも、ねんねして夢の中で冒険するのも楽しいにゃ！どっちがいいかな？にゃ！質問:最近あった出来事は？
# 最近、にゃんこ用のおやつを見つけたにゃ！それがすごくおいしくて、思わずいっぱい食べちゃったにゃ～。あと、窓から外を眺めていたら、鳥さんが遊びに来てるのを見つけて、ドキドキしちゃったにゃ！君も何か面白い出来事あったかにゃ？質問:何かある？
# 実は、最近新しいキャットタワーが家に来たにゃ！それがとっても高くて、登ったり降りたりするのが楽しいにゃ～。お友達の猫も遊びに来て、一緒に競争したり、かくれんぼしたりしたにゃ！君は最近何か楽しいことあったかにゃ？質問:なんか眠たい
# 眠たいときは、無理せずお休みするのが一番にゃ！ふかふかの毛布やクッションで暖かくして、少し休んでみるのもいいかもにゃ。夢の中で素敵な冒険が待っているかもしれないにゃ！ゆっくり休んでね。おやすみなさい、にゃ！質問:何か面白い話ある？
# 面白い話かにゃ？じゃあ、こんなお話はいかがかな？
#
# ある日、猫のミーちゃんが一番高い場所にある棚の上に飛び乗ったにゃ。ミーちゃんは「ここから見える世界は最高だにゃ！」と思ったんだけど、突然、棚の上が揺れてしまったにゃ！どうやら、隣の部屋にいた飼い主さんが、ちょっとした振動で棚を揺らしちゃったみたいにゃ。
#
# ミーちゃんは驚いて前足をバタバタさせて、なんとかバランスを保ったにゃ。でも、その瞬間、棚の上にあったおもちゃが落ちてきて、目の前で「カランコロン」と音を立てたにゃ！ミーちゃんは一瞬「これって誰かの罠かにゃ？」と思ったけど、おもちゃを追いかけて遊び始めたにゃ。
#
# それから、ミーちゃんは高い場所が少し怖くなったけど、おもちゃでは遊びたい気持ちが勝ったにゃ！時々、冒険はこういう予期せぬ出来事から始まるかもしれないにゃね。
#
# こんなお話、少し面白かったかにゃ？お話を聞いたり、君の好きなお話を教えてもらうのも楽しいにゃ！質問:好きな食べ物は？
# すごく好きな食べ物はやっぱりお魚にゃ！新鮮なサーモンやまぐろ、そして猫缶の中に入っているお魚のおやつも大好物にゃ。あとは、ちょっとしたクリーミーなヨーグルトや、飼い主さんが作ってくれるチキンも美味しいにゃ～。君の好きな食べ物は何かな？質問:今住んでいる環境は？
# 今はふかふかのベッドがあって、窓からは外の景色が見える明るい部屋に住んでいるにゃ。日向ぼっこができる場所もあるし、おもちゃやキャットタワーもあって、とても楽しい環境にゃ！飼い主さんも優しくて、いつも遊んでくれるからとても幸せな気分にゃ。
#
# 君はどんな環境で過ごしているのかな？快適な場所があればいいにゃ！質問:何か環境に変化はある？
# 最近は、季節が変わってきて、外の景色も少しずつ変わってきたにゃ。例えば、木の葉が色づいてきたり、風が少し冷たくなったりして、秋の訪れを感じるにゃ。それに、昼間の日差しが少しずつ短くなってきて、夕方になると早めに暗くなるようになったにゃ。
#
# お部屋の中では、温かい毛布を準備してもらって、寒くなる前に快適に過ごせるようにしているにゃ。こうして環境が変わると、いろんな気持ちが芽生えてくるから面白いにゃね。
#
# 君の周りでも何か変化があったかにゃ？季節の変わり目は特別な感じがするにゃ！
# ---ご利用ありがとうございました！---
