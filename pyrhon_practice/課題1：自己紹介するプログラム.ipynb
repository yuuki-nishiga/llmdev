# %%
name = input("名前を入力してください")
print(f"名前を入力してください：{name}")
age = int(input("年齢を入力してください"))
print(f"現在の年齢を入力してください：{age}")

print("はじめまして、", name ,"と申します。年齢は", age ,"です。来年は", age + 1, "になります。")
# Out:
# 名前を入力してください：taro kirameki
# 現在の年齢を入力してください：25
# はじめまして、 taro kirameki と申します。年齢は 25 です。来年は 26 になります。
